# %% [markdown]
# # Examples of Image Reconstruction

# %% [markdown]
# Image: **'horses.jpg'**
#
# Input Data: **5%**

# %%
# %run Image_Reconstruction.py
# Out:
# Shape of Image:  (321, 481, 3)
# Number of samples:  7720
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Iteration number:  5
# Iteration number:  6
# Iteration number:  7
# Iteration number:  8
# Lossy conversion from float64 to uint8. Range [7.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [7.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Execution time: 16 sec

# %% [markdown]
# Image: **'horses.jpg'**
#
# Input Data: **50%**

# %%
# %run Image_Reconstruction.py
# Out:
# Shape of Image:  (321, 481, 3)
# Number of samples:  77200
# Iteration number:  1
# Iteration number:  2
# Lossy conversion from float64 to uint8. Range [1.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [1.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Execution time: 5 sec

# %% [markdown]
# Image: **'elephants.jpg'**
#
# Input Data: **5%**

# %%
# %run Image_Reconstruction.py
# Out:
# Shape of Image:  (321, 481, 3)
# Number of samples:  7720
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Iteration number:  4
# Iteration number:  5
# Iteration number:  6
# Iteration number:  7
# Iteration number:  8
# Lossy conversion from float64 to uint8. Range [11.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [11.0, 249.0]. Convert image to uint8 prior to saving to suppress this warning.
# Execution time: 16 sec

# %% [markdown]
# Image: **'elephants.jpg'**
#
# Input Data: **25%**

# %%
# %run Image_Reconstruction.py
# Out:
# Shape of Image:  (321, 481, 3)
# Number of samples:  38600
# Iteration number:  1
# Iteration number:  2
# Iteration number:  3
# Lossy conversion from float64 to uint8. Range [13.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [13.0, 255.0]. Convert image to uint8 prior to saving to suppress this warning.
# Execution time: 7 sec
